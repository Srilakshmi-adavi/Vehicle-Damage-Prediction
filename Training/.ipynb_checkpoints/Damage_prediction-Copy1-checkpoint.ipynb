# %%
import os
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
import torchvision.models as models
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
image_transfoms=transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2,contrast=0.2),
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset_path="./dataset"
dataset=datasets.ImageFolder(root=dataset_path, transform=image_transfoms)
len(dataset)
# Out:
# 2300

# %%
dataset.classes
# Out:
# ['F_Breakage', 'F_Crushed', 'F_Normal', 'R_Breakage', 'R_Crushed', 'R_Normal']

# %%
num_classes=len(dataset.classes)
num_classes
# Out:
# 6

# %%
train_size=int(0.75*len(dataset))
val_size=len(dataset)-train_size

train_size, val_size
# Out:
# (1725, 575)

# %%
from torch.utils.data import random_split
train_dataset, val_dataset=random_split(dataset, [train_size, val_size])

# %%
train_loader=DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader=DataLoader(val_dataset, batch_size=32, shuffle=True)

# %%
for images, labels in train_loader:
    print(images.shape)
    print(labels.shape)
    break
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32])

# %%
labels[0]
# Out:
# tensor(2)

# %%
images[0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
images[0].permute(1,2,0).shape
# Out:
# torch.Size([224, 224, 3])

# %%
plt.imshow(images[0].permute(1,2,0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8952821..2.3785625].

# %% [markdown]
# ## Model1: CNN

# %%
def train_model(model, criterion, optimizer, epochs=5):
    start = time.time()

    for epoch in range(epochs):
        model.train()
        running_loss=0.0
        for batch_num, (images, labels) in enumerate(train_loader):

            optimizer.zero_grad()
            
            outputs=model(images)
            loss=criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            if (batch_num+1 % 10) == 0:
                print(f"Batch Number: {batch_num+1}, Epoch:{epoch+1}, Loss:{loss.item():.2f} ")
                

            running_loss +=loss.item() * images.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch: [{epoch+1}/{epoch}], Average_loss:{epoch_loss:.4f}")

        model.eval()
        correct=0
        total=0
        all_labels=[]
        all_predictions=[]
        with torch.no_grad():
            for images, labels in val_loader:
                outputs=model(images)
                _, predicted=torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted==labels).sum().item()
                all_labels.extend(labels)
                all_predictions.extend(predicted)
            print(f"**** Validation Accuracy:{100*correct / total:.2f}% **** ")

    end=time.time()
    print(f"Execution Time:{start-end} Seconds ")
    return all_labels, all_predictions

# %%
all_labels, all_predicted = train_model(model, criterion, optimizer, epochs=5)
# Out:
# Epoch: [1/0], Average_loss:1.1566
# **** Validation Accuracy:51.48% ****
# Epoch: [2/1], Average_loss:1.0133
# **** Validation Accuracy:53.39% ****
# Epoch: [3/2], Average_loss:0.9190
# **** Validation Accuracy:52.70% ****
# Epoch: [4/3], Average_loss:0.8430
# **** Validation Accuracy:51.83% ****
# Epoch: [5/4], Average_loss:0.8187
# **** Validation Accuracy:54.09% ****
# Execution Time:-12518.205595254898 Seconds

# %%
model=CarClassifierEfficientNet(num_classes=num_classes)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(filter(lambda p:p.requires_grad, model.parameters()), lr=0.001)

train_model(model, criterion, optimizer, epochs=10)

# %% [markdown]
# ## Model Training and Hyperparameter Tuning

# %%
class CarClassifierResNet(nn.Module):
    def __init__(self, num_classes, dropout_rate=0.5):
        super().__init__()
        self.model=models.resnet50(weights='DEFAULT')
        for param in self.model.parameters():
            param.requires_grad=False

        for param in self.model.layer4.parameters():
            param.requires_grad=True

        self.model.fc=nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.model.fc.in_features, num_classes), 
        )

    def forward(x):
        x=self.model(x)
        return x

# %%
model=CarClassifierResNet(num_classes=num_classes)
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(filter(lambda p:p.requires_grad, model.parameters()), lr=0.001)

train_model(model, criterion, optimizer, epochs=10)
